# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/_cafe_sales.csv')
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
# Apply IQR method
 Q1 = df['total spent'].quantile(0.25)
 Q3 = df['total spent'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df['total spent_iqr_outlier'] = (df['total spent'] < (Q1 - 1.5 * IQR)) | (df['total spent'] > (Q3 + 1.5 * IQR))
print(f'{col}_iqr_outlier')
# Out:
#   File "<ipython-input-51-7c03ff98d2cc>", line 2
#     Q1 = df['total spent'].quantile(0.25)
#     ^
# IndentationError: unexpected indent

# %%
# Display outliers
outliers = df[(df['total spent_iqr_outlier']) | (df['quantity_iqr_outlier'])]

print(outliers[['total spent', 'quantity', 'total spent_iqr_outlier', 'quantity_iqr_outlier']])

# %%
# Treat Outliers
def treat_outliers_iqr(df, columns):
    for col in columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        df[f'{col}_iqr_outlier'] = (df[col] < (Q1 - 1.5 * IQR)) | (df[col] > (Q3 + 1.5 * IQR))
        df[col] = df[col].apply(lambda x: lower_bound if x < lower_bound else (upper_bound if x > upper_bound else x))
    return df
